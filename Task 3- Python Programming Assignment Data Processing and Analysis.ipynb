# %% [markdown]
# ## Task 3- Python Programming Assignment Data Processing and Analysis

# %% [markdown]
# ## Problem Statement 1: Employee Performance Bonus Eligibility

# %%
employees = {
    "Ravi": 92,
    "Anita": 88,
    "Kiran": 92,
    "Suresh": 85
}

# Find the highest performance score
highest_score = max(employees.values())

# Find all employees with the highest score (handling ties)
top_performers = [name for name, score in employees.items() if score == highest_score]

# Display the results
print(f"Top Performers Eligible for Bonus: {', '.join(top_performers)} (Score: {highest_score})")
# Out:
# Top Performers Eligible for Bonus: Ravi, Kiran (Score: 92)

# %% [markdown]
# ## Problem Statement 2: Search Query Keyword Analysis

# %%
import collections
import string

search_query = "Buy mobile phone buy phone online"

# Convert to lowercase
cleaned_query = search_query.lower()

# Ignore common punctuation
# Using str.translate and str.maketrans to remove punctuation
translator = str.maketrans('', '', string.punctuation)
cleaned_query = cleaned_query.translate(translator)

# Split into keywords and count frequency
keywords = cleaned_query.split()
keyword_counts = collections.Counter(keywords)

# Display only keywords searched more than once
result = {word: count for word, count in keyword_counts.items() if count > 1}

print(result)
# Out:
# {'buy': 2, 'phone': 2}

# %% [markdown]
# ## Problem Statement 3: Sensor Data Validation

# %%
sensor_readings = [3, 4, 7, 8, 10, 12, 5]

valid_readings = []
for hour_index, reading_value in enumerate(sensor_readings):
    if reading_value % 2 == 0:  # Check if the reading is an even number
        valid_readings.append((hour_index, reading_value))

# Display the results
print(f"Valid Sensor Readings (Hour, Value):\n{valid_readings}")
# Out:
# Valid Sensor Readings (Hour, Value):
# [(1, 4), (3, 8), (4, 10), (5, 12)]

# %% [markdown]
# ## Problem Statement 4: Email Domain Usage Analysis

# %%
emails = [
    "ravi@gmail.com",
    "anita@yahoo.com",
    "kiran@gmail.com",
    "suresh@gmail.com",
    "meena@yahoo.com"
]

# Extract domains and count occurrences
domain_counts = {}
for email in emails:
    domain = email.split('@')[1]
    domain_counts[domain] = domain_counts.get(domain, 0) + 1

# Calculate total number of emails
total_emails = len(emails)

# Calculate and display percentage usage for each domain
for domain, count in domain_counts.items():
    percentage = (count / total_emails) * 100
    print(f"{domain}: {percentage:.0f}%")
# Out:
# gmail.com: 60%
# yahoo.com: 40%

# %% [markdown]
# ## Problem Statement 5: Sales Spike Detection

# %%
sales = [1200, 1500, 900, 2200, 1400, 3000]

# Calculate the average daily sales
average_sales = sum(sales) / len(sales)

# Define the spike threshold (30% above average)
spike_threshold = average_sales * 1.30

print("Sales Spikes Detected:")
# Detect days where sales are more than 30% above average
for day_index, sale_value in enumerate(sales):
    if sale_value > spike_threshold:
        # Display the day number (1-based index) and sale value
        print(f"Day {day_index + 1}: {sale_value}")
# Out:
# Sales Spikes Detected:
# Day 6: 3000

# %% [markdown]
# ## Problem Statement 6: Duplicate User ID Detection

# %%
import collections

user_ids = ["user1", "user2", "user1", "user3", "user1", "user3"]

# Count the frequency of each user ID
id_counts = collections.Counter(user_ids)

print("Duplicate User IDs Detected:")
# Iterate through the counts and display duplicates
for user_id, count in id_counts.items():
    if count > 1:
        print(f"{user_id} → {count} times")
# Out:
# Duplicate User IDs Detected:
# user1 → 3 times
# user3 → 2 times
